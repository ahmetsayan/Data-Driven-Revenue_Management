# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/content/Q6 Data.xlsx')

# %%
data
# Out:
#           Date  From  Price Level  # of Trips
# 0       Monday  MiMA           95         237
# 1     Tuesday   MiMA          145         134
# 2    Wednesday  MiMA           85         306
# 3     Thursday  MiMA          110         239
# 4       Friday  MiMA          155         119
# ..         ...   ...          ...         ...
# 125     Monday   UES           95          93
# 126   Tuesday    UES           65         146
# 127  Wednesday   UES          115          97
# 128   Thursday   UES          140          47
# 129     Friday   UES           90         105
#
# [130 rows x 4 columns]

# %%
data.dropna(axis=1, how='all', inplace=True)
data.dropna(axis=0 , how='all', inplace =True)

# %%
data
# Out:
#           Date  From  Price Level  # of Trips
# 0       Monday  MiMA           95         237
# 1     Tuesday   MiMA          145         134
# 2    Wednesday  MiMA           85         306
# 3     Thursday  MiMA          110         239
# 4       Friday  MiMA          155         119
# ..         ...   ...          ...         ...
# 125     Monday   UES           95          93
# 126   Tuesday    UES           65         146
# 127  Wednesday   UES          115          97
# 128   Thursday   UES          140          47
# 129     Friday   UES           90         105
#
# [130 rows x 4 columns]

# %%
X_features = list(data.columns)
X_features.remove('# of Trips')
encoded_data = pd.get_dummies(data[X_features], drop_first = True).astype(int)

# %%
encoded_data
# Out:
#      Price Level  Date_Monday  Date_Thursday  Date_Tuesday   Date_Wednesday  \
# 0             95            1              0              0               0
# 1            145            0              0              1               0
# 2             85            0              0              0               1
# 3            110            0              1              0               0
# 4            155            0              0              0               0
# ..           ...          ...            ...            ...             ...
# 125           95            1              0              0               0
# 126           65            0              0              1               0
# 127          115            0              0              0               1
# 128          140            0              1              0               0
# 129           90            0              0              0               0
#
#      From_UES
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 125         1
# 126         1
# 127         1
# 128         1
# 129         1
#
# [130 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm
import seaborn as sn
from sklearn.model_selection import train_test_split

X = sm.add_constant(encoded_data)
Y = data["# of Trips"]

# %%
sm.OLS(Y,X).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             # of Trips   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     313.3
# Date:                Sat, 29 Mar 2025   Prob (F-statistic):           5.23e-72
# Time:                        17:12:26   Log-Likelihood:                -587.76
# No. Observations:                 130   AIC:                             1190.
# Df Residuals:                     123   BIC:                             1210.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            460.5052      8.717     52.829      0.000     443.251     477.760
# Price Level       -2.1477      0.059    -36.668      0.000      -2.264      -2.032
# Date_Monday       -3.0669      6.344     -0.483      0.630     -15.624       9.491
# Date_Thursday      4.0345      6.354      0.635      0.527      -8.542      16.611
# Date_Tuesday      -9.1980      6.356     -1.447      0.150     -21.780       3.384
# Date_Wednesday    -5.4183      6.345     -0.854      0.395     -17.978       7.142
# From_UES        -151.0253      4.329    -34.884      0.000    -159.595    -142.456
# ==============================================================================
# Omnibus:                        4.981   Durbin-Watson:                   2.423
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                5.079
# Skew:                           0.471   Prob(JB):                       0.0789
# Kurtosis:                       2.774   Cond. No.                         667.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
